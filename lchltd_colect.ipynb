# %%
import numpy as np
import pandas as pd
import openpyxl 
import os
# %run ccp_func.ipynb

# %%
def lchltd_colect(quarter):
    #quarter = format: 'Q3-2017'
    
    ccp = 'lchltd'
    reverse = quarter.split('-')
    reverse = reverse[1] + '_' + reverse[0]
    
    reverse2 = quarter.split('-')
    reverse2 = reverse2[1] + reverse2[0]
    
    try:
        #basic
        b_file = pd.read_excel('../CCP/data/' + quarter.upper() + '/LCH.Clearnet_LTD-' + 
                               quarter.lower() + '.xlsx', sheet_name=ccp.upper() + '_AggregatedDataFile' + reverse2.upper())
        #files in use
        a_file = pd.read_excel('../CCP/data/' + quarter.upper() + '/LCH.Clearnet_LTD-' +
                               quarter.lower() + '.xlsx', 
                               sheet_name=ccp.upper() + '_DataFile_4_4a_' + reverse.upper())
        c_file = pd.read_excel('../CCP/data/' + quarter.upper() + '/LCH.Clearnet_LTD-' +
                               quarter.lower() + '.xlsx', 
                               sheet_name=ccp.upper() + '_DataFile_6_1_' + reverse.upper())
        d_file = pd.read_excel('../CCP/data/' + quarter.upper() + '/LCH.Clearnet_LTD-' +
                               quarter.lower() + '.xlsx', 
                               sheet_name=ccp.upper() + '_DataFile_6_2_' + reverse.upper())
        e_file = pd.read_excel('../CCP/data/' + quarter.upper() + '/LCH.Clearnet_LTD-' +
                               quarter.lower() + '.xlsx', 
                               sheet_name=ccp.upper() + '_DataFile_18_' + reverse.upper())
        g_file = pd.read_excel('../CCP/data/' + quarter.upper() + '/LCH.Clearnet_LTD-' + 
                               quarter.lower() + '.xlsx', 
                               sheet_name=ccp.upper() + '_DataFile_23_' + reverse.upper())
        ex_rate = pd.read_excel('../CCP/data/kursy-walutowe-CCP.xlsx', sheet_name='Arkusz1')
    except:
        #Q3-2016
        if quarter == 'Q3-2016':
            #basic
            b_file = pd.read_excel('../CCP/data/' + quarter.upper() + '/LCH.Clearnet_LTD-' +
                                       quarter.lower() + '.xlsx', sheet_name='AggregatedDataFile')
            #files in use
            a_file = pd.read_excel('../CCP/data/' + quarter.upper() + '/LCH.Clearnet_LTD-' +
                                   quarter.lower() + '.xlsx', 
                                   sheet_name=ccp.upper() + '_Datafile_4_4a_' + reverse2.upper())
            c_file = pd.read_excel('../CCP/data/' + quarter.upper() + '/LCH.Clearnet_LTD-' +
                                   quarter.lower() + '.xlsx', 
                                   sheet_name=ccp.upper() + '_Datafile_6_1_' + reverse2.upper())
            d_file = pd.read_excel('../CCP/data/' + quarter.upper() + '/LCH.Clearnet_LTD-' +
                                   quarter.lower() + '.xlsx', 
                                   sheet_name=ccp.upper() + '_Datafile_6_2_' + reverse2.upper())
            e_file = pd.read_excel('../CCP/data/' + quarter.upper() + '/LCH.Clearnet_LTD-' +
                                   quarter.lower() + '.xlsx', 
                                   sheet_name=ccp.upper() + '_Datafile_18_' + reverse2.upper())
            g_file = pd.read_excel('../CCP/data/' + quarter.upper() + '/LCH.Clearnet_LTD-' + 
                                   quarter.lower() + '.xlsx', 
                                   sheet_name=ccp.upper() + '_Datafile_23_' + reverse2.upper())
            ex_rate = pd.read_excel('../CCP/data/kursy-walutowe-CCP.xlsx', sheet_name='Arkusz1')
        else:
            #basic
            b_file = pd.read_excel('../CCP/data/' + quarter.upper() + '/LCH.Clearnet_LTD-' +
                                       quarter.lower() + '.xlsx', sheet_name='AggregatedDataFile')
            #files in use
            a_file = pd.read_excel('../CCP/data/' + quarter.upper() + '/LCH.Clearnet_LTD-' +
                                       quarter.lower() + '.xlsx', 
                                       sheet_name='CCP1_DataFile_4.4a')
            c_file = pd.read_excel('../CCP/data/' + quarter.upper() + '/LCH.Clearnet_LTD-' +
                                       quarter.lower() + '.xlsx', 
                                       sheet_name='CCP1_DataFile_6.1')
            d_file = pd.read_excel('../CCP/data/' + quarter.upper() + '/LCH.Clearnet_LTD-' +
                                       quarter.lower() + '.xlsx', 
                                       sheet_name='CCP1_DataFile_6.2')
            e_file = pd.read_excel('../CCP/data/' + quarter.upper() + '/LCH.Clearnet_LTD-' +
                                       quarter.lower() + '.xlsx', 
                                       sheet_name='CCP1_DataFile_18')
            g_file = pd.read_excel('../CCP/data/' + quarter.upper() + '/LCH.Clearnet_LTD-' +
                                       quarter.lower() + '.xlsx', 
                                       sheet_name='CCP1_DataFile_23')
            ex_rate = pd.read_excel('../CCP/data/kursy-walutowe-CCP.xlsx', sheet_name='Arkusz1')
            
    f_file = pd.DataFrame({'CCP':ccp.upper()}, index=[0,1,2,3,4])
    f_file['quarter'] = quarter
    f_file['clearning service'] = ['commodities', 'equities', 'fixed income', 'OTC FX', 'interest rates']
    b_file = b_file.drop([0]).reset_index() #general description
    
    #to EUR
    add_ex_rate(b_file, ex_rate, quarter)
    try:
        b_file['4.1.1'] = b_file['4.1.1'] // b_file['ex_rate']
        b_file['4.1.2'] = b_file['4.1.2'] // b_file['ex_rate']
        b_file['4.1.3'] = b_file['4.1.3'] // b_file['ex_rate']
        b_file['4.1.4'] = b_file['4.1.4'] // b_file['ex_rate']
        b_file['4.1.5'] = b_file['4.1.5'] // b_file['ex_rate']
        b_file['4.1.6'] = b_file['4.1.6'] // b_file['ex_rate']
        b_file['4.1.7'] = b_file['4.1.7'] // b_file['ex_rate']
        b_file['4.1.8'] = b_file['4.1.8'] // b_file['ex_rate']
        b_file['4.1.9'] = b_file['4.1.9'] // b_file['ex_rate']
        b_file['4.1.10'] = b_file['4.1.10'] // b_file['ex_rate']
    except:
        b_file['4.1.1'] = b_file['4_1_1'] // b_file['ex_rate']
        b_file['4.1.2'] = b_file['4_1_2'] // b_file['ex_rate']
        b_file['4.1.3'] = b_file['4_1_3'] // b_file['ex_rate']
        b_file['4.1.4'] = b_file['4_1_4'] // b_file['ex_rate']
        b_file['4.1.5'] = b_file['4_1_5'] // b_file['ex_rate']
        b_file['4.1.6'] = b_file['4_1_6'] // b_file['ex_rate']
        b_file['4.1.7'] = b_file['4_1_7'] // b_file['ex_rate']
        b_file['4.1.8'] = b_file['4_1_8'] // b_file['ex_rate']
        b_file['4.1.9'] = b_file['4_1_9'] // b_file['ex_rate']
        b_file['4.1.10'] = b_file['4_1_10'] // b_file['ex_rate']
        
    try:
        f_file['4.1.1'] = b_file['4.1.1']
        f_file['4.1.2'] = b_file['4.1.2']
        f_file['4.1.3'] = b_file['4.1.3']
        f_file['4.1.4'] = b_file['4.1.4']
        f_file['4.1.5'] = b_file['4.1.5']
        f_file['4.1.6'] = b_file['4.1.6']
        f_file['4.1.7'] = b_file['4.1.7']
        f_file['4.1.8'] = b_file['4.1.8']
        f_file['4.1.9'] = b_file['4.1.9']
        f_file['4.1.10'] = b_file['4.1.10']
    except:
        f_file['4.1.1'] = b_file['4_1_1']
        f_file['4.1.2'] = b_file['4_1_2']
        f_file['4.1.3'] = b_file['4_1_3']
        f_file['4.1.4'] = b_file['4_1_4']
        f_file['4.1.5'] = b_file['4_1_5']
        f_file['4.1.6'] = b_file['4_1_6']
        f_file['4.1.7'] = b_file['4_1_7']
        f_file['4.1.8'] = b_file['4_1_8']
        f_file['4.1.9'] = b_file['4_1_9']
        f_file['4.1.10'] = b_file['4_1_10']
        
    add_ex_rate(a_file, ex_rate, quarter)
    try:
        a_file['4.4.7'] = a_file['4.4.7'] // a_file['ex_rate']
    except:
        a_file['4.4.7'] = a_file['4_4_7'] // a_file['ex_rate']
    
    add_ex_rate(c_file, ex_rate, quarter)
    try:
        c_file['6.1.1'] = c_file['6.1.1'] // c_file['ex_rate']
    except:
        c_file['6.1.1'] = c_file['6_1_1'] // c_file['ex_rate']
    
    add_ex_rate(d_file, ex_rate, quarter)
    try:
        d_file['6.2.15'] = d_file['6.2.15'] // d_file['ex_rate']
    except:
        d_file['6.2.15'] = d_file['6_2_15'] // d_file['ex_rate']
    
    add_ex_rate(g_file, ex_rate, quarter)
    try:
        g_file['23.1.2'] = g_file['23.1.2'] // g_file['ex_rate']
        g_file['23.2.1'] = g_file['23.2.1'] // g_file['ex_rate']
    except:
        g_file['23.1.2'] = g_file['23_1_2'] // g_file['ex_rate']
        g_file['23.2.1'] = g_file['23_2_1'] // g_file['ex_rate']
        
    # 4.4.7.PDA & 4.4.7.MA
    try:
        f_file['4.4.7.PDA'] = a_file[a_file.Description == 'PeakDayAmountInPast12Months'].reset_index()['4.4.7']
        f_file['4.4.7.MA'] = a_file[a_file.Description == 'MeanAverageOverPrevious12Months'].reset_index()['4.4.7']
    except:
        #Q1-2017 different
        f_file['4.4.7.PDA'] = a_file[a_file.Description == 'PeakDayAmountInPast12Months'].reset_index()['4_4_7']
        f_file['4.4.7.MA'] = a_file[a_file.Description == 'MeanAverageOverPrevious12Months'].reset_index()['4_4_7']

    #6.1.1.CLIENT = 'Client_Net' + 'Client_Gross'
    try:
        CD_CLIENT= sum(c_file[c_file.Description.isin(['Client_Net', 'Client_Gross']) & (c_file.ReportLevelIdentifier == 'Commodities')]['6.1.1'])
        FI_CLIENT= sum(c_file[c_file.Description.isin(['Client_Net', 'Client_Gross']) & (c_file.ReportLevelIdentifier == 'Equities')]['6.1.1'])
        OTC_CLIENT= sum(c_file[c_file.Description.isin(['Client_Net', 'Client_Gross']) & (c_file.ReportLevelIdentifier == 'Fixed_Income')]['6.1.1'])
        CG_CLIENT= sum(c_file[c_file.Description.isin(['Client_Net', 'Client_Gross']) & (c_file.ReportLevelIdentifier == 'OTC_FX')]['6.1.1'])
        IR_CLIENT= sum(c_file[c_file.Description.isin(['Client_Net', 'Client_Gross']) & (c_file.ReportLevelIdentifier == 'Interest_Rates')]['6.1.1'])

        f_file['6.1.1.CLIENT'] = [CD_CLIENT, FI_CLIENT, OTC_CLIENT, CG_CLIENT, IR_CLIENT]

        f_file['6.1.1.TOTAL'] = c_file[c_file.Description == 'Total'].reset_index()['6.1.1']

        #6.2.15.PRE & POST
        f_file['6.2.15.PRE'] = float(d_file[d_file.Description.isin(['TotalIM_PreHaircut'])]['6.2.15'].values)
        f_file['6.2.15.POST'] = float(d_file[d_file.Description.isin(['TotalIM_PostHaircut'])]['6.2.15'].values)
    except:
        #Q1-2017
        CD_CLIENT= sum(c_file[c_file.Description.isin(['Client_Net', 'Client_Gross']) & (c_file.ReportLevelIdentifier == 'Commodities')]['6_1_1'])
        FI_CLIENT= sum(c_file[c_file.Description.isin(['Client_Net', 'Client_Gross']) & (c_file.ReportLevelIdentifier == 'Equities')]['6_1_1'])
        OTC_CLIENT= sum(c_file[c_file.Description.isin(['Client_Net', 'Client_Gross']) & (c_file.ReportLevelIdentifier == 'Fixed_Income')]['6_1_1'])
        CG_CLIENT= sum(c_file[c_file.Description.isin(['Client_Net', 'Client_Gross']) & (c_file.ReportLevelIdentifier == 'OTC_FX')]['6_1_1'])
        IR_CLIENT= sum(c_file[c_file.Description.isin(['Client_Net', 'Client_Gross']) & (c_file.ReportLevelIdentifier == 'Interest_Rates')]['6_1_1'])
    
        f_file['6.1.1.CLIENT'] = [CD_CLIENT, FI_CLIENT, OTC_CLIENT, CG_CLIENT, IR_CLIENT]
    
        f_file['6.1.1.TOTAL'] = c_file[c_file.Description == 'Total'].reset_index()['6_1_1']
    
        #6.2.15.PRE & POST
        f_file['6.2.15.PRE'] = float(d_file[d_file.Description.isin(['TotalIM_PreHaircut'])]['6_2_15'].values)
        f_file['6.2.15.POST'] = float(d_file[d_file.Description.isin(['TotalIM_PostHaircut'])]['6_2_15'].values)
    
    try:
    #number of CCP
        f_file['18.1.1.1'] = b_file['18_1_1_1']
        f_file['18.1.1.2'] = b_file['18_1_1_2']

        #number od CCP participants (average)
        f_file['18.1.2.2'] = b_file['18_1_2_2']

        #number of clients
        f_file['19.1.1'] = b_file['19_1_1']
        f_file['19.1.2'] = b_file['19_1_2']
    except:
        #Q4-2016
        f_file['18.1.1.1'] = b_file['18.1.1.1']
        f_file['18.1.1.2'] = b_file['18.1.1.2']

        #number od CCP participants (average)
        f_file['18.1.2.2'] = b_file['18.1.2.2']

        #number of clients
        f_file['19.1.1'] = b_file['19.1.1']
        f_file['19.1.2'] = b_file['19.1.2']
    
    try:
        #23.1.2.OTC & ETD
        CDS_OTC = sum(g_file[(g_file.Description.isin(['OTC'])) & g_file.ReportLevelIdentifier.isin(['EquityClear'])]['23.1.2'])
        EC_OTC = sum(g_file[(g_file.Description.isin(['OTC'])) & g_file.ReportLevelIdentifier.isin(['ForexClear'])]['23.1.2'])
        LD_OTC = sum(g_file[(g_file.Description.isin(['OTC'])) & g_file.ReportLevelIdentifier.isin(['Interest Rates'])]['23.1.2'])

        f_file['23.1.2.OTC'] = [None, CDS_OTC, None, EC_OTC, LD_OTC]

        CDS_OTC = sum(g_file[(g_file.Description.isin(['ETD'])) & g_file.ReportLevelIdentifier.isin(['EquityClear'])]['23.1.2'])
        EC_OTC = sum(g_file[(g_file.Description.isin(['ETD'])) & g_file.ReportLevelIdentifier.isin(['ForexClear'])]['23.1.2'])
        LD_OTC = sum(g_file[(g_file.Description.isin(['ETD'])) & g_file.ReportLevelIdentifier.isin(['Interest Rates'])]['23.1.2'])

        f_file['23.1.2.ETD'] = [None, CDS_OTC, None, EC_OTC, LD_OTC]

        #23.2.1.OTC & ETD
        CDS_OTC = sum(g_file[(g_file.Description.isin(['OTC'])) & g_file.ReportLevelIdentifier.isin(['EquityClear'])]['23.2.1'])
        EC_OTC = sum(g_file[(g_file.Description.isin(['OTC'])) & g_file.ReportLevelIdentifier.isin(['ForexClear'])]['23.2.1'])
        LD_OTC = sum(g_file[(g_file.Description.isin(['OTC'])) & g_file.ReportLevelIdentifier.isin(['Interest Rates'])]['23.2.1'])

        f_file['23.2.1.OTC'] = [None, CDS_OTC, None, EC_OTC, LD_OTC]

        CDS_OTC = sum(g_file[(g_file.Description.isin(['ETD'])) & g_file.ReportLevelIdentifier.isin(['EquityClear'])]['23.2.1'])
        EC_OTC = sum(g_file[(g_file.Description.isin(['ETD'])) & g_file.ReportLevelIdentifier.isin(['ForexClear'])]['23.2.1'])
        LD_OTC = sum(g_file[(g_file.Description.isin(['ETD'])) & g_file.ReportLevelIdentifier.isin(['Interest Rates'])]['23.2.1'])

        f_file['23.2.1.ETD'] = [None, CDS_OTC, None, EC_OTC, LD_OTC]
    except:
        #Q1-2017

        #23.1.2.OTC & ETD
        CDS_OTC = sum(g_file[(g_file.Description.isin(['OTC'])) & g_file.ReportLevelIdentifier.isin(['EquityClear'])]['23_1_2'])
        EC_OTC = sum(g_file[(g_file.Description.isin(['OTC'])) & g_file.ReportLevelIdentifier.isin(['ForexClear'])]['23_1_2'])
        LD_OTC = sum(g_file[(g_file.Description.isin(['OTC'])) & g_file.ReportLevelIdentifier.isin(['Interest Rates'])]['23_1_2'])

        f_file['23.1.2.OTC'] = [None, CDS_OTC, None, EC_OTC, LD_OTC]

        CDS_OTC = sum(g_file[(g_file.Description.isin(['ETD'])) & g_file.ReportLevelIdentifier.isin(['EquityClear'])]['23_1_2'])
        EC_OTC = sum(g_file[(g_file.Description.isin(['ETD'])) & g_file.ReportLevelIdentifier.isin(['ForexClear'])]['23_1_2'])
        LD_OTC = sum(g_file[(g_file.Description.isin(['ETD'])) & g_file.ReportLevelIdentifier.isin(['Interest Rates'])]['23_1_2'])

        f_file['23.1.2.ETD'] = [None, CDS_OTC, None, EC_OTC, LD_OTC]

        #23.2.1.OTC & ETD
        CDS_OTC = sum(g_file[(g_file.Description.isin(['OTC'])) & g_file.ReportLevelIdentifier.isin(['EquityClear'])]['23_2_1'])
        EC_OTC = sum(g_file[(g_file.Description.isin(['OTC'])) & g_file.ReportLevelIdentifier.isin(['ForexClear'])]['23_2_1'])
        LD_OTC = sum(g_file[(g_file.Description.isin(['OTC'])) & g_file.ReportLevelIdentifier.isin(['Interest Rates'])]['23_2_1'])

        f_file['23.2.1.OTC'] = [None, CDS_OTC, None, EC_OTC, LD_OTC]

        CDS_OTC = sum(g_file[(g_file.Description.isin(['ETD'])) & g_file.ReportLevelIdentifier.isin(['EquityClear'])]['23_2_1'])
        EC_OTC = sum(g_file[(g_file.Description.isin(['ETD'])) & g_file.ReportLevelIdentifier.isin(['ForexClear'])]['23_2_1'])
        LD_OTC = sum(g_file[(g_file.Description.isin(['ETD'])) & g_file.ReportLevelIdentifier.isin(['Interest Rates'])]['23_2_1'])

        f_file['23.2.1.ETD'] = [None, CDS_OTC, None, EC_OTC, LD_OTC]
    
    ccp_save(ccp, quarter, f_file)
