# %%
import numpy as np
import pandas as pd
import openpyxl 
import os
# %run ccp_func.ipynb

# %%
def ccg_colect(quarter):
    
    #quarter = format: 'Q3-2017'
    
    ccp = 'CCG'
    
    #for Q2-2017 and Q3-2017
    if quarter == 'Q2-2017' or quarter == 'Q3-2017':
        #basic
        b_file = pd.read_excel('../CCP/data/' + quarter.upper() + '/' + ccp.upper() + '_' + 
                               quarter.lower() + '.xlsx', sheet_name='AggregatedDataFile')
        #files in use
        a_file = pd.read_excel('../CCP/data/' + quarter.upper() + '/' + ccp.upper() + '_' + 
                               quarter.lower() + '.xlsx', 
                               sheet_name='CCP1_DataFile_4.4a')
        c_file = pd.read_excel('../CCP/data/' + quarter.upper() + '/' + ccp.upper() + '_' + 
                               quarter.lower() + '.xlsx', 
                               sheet_name='CCP1_DataFile_6.1')
        d_file = pd.read_excel('../CCP/data/' + quarter.upper() + '/' + ccp.upper() + '_' + 
                               quarter.lower() + '.xlsx', 
                               sheet_name='CCP1_DataFile_6.2')
        e_file = pd.read_excel('../CCP/data/' + quarter.upper() + '/' + ccp.upper() + '_' + 
                               quarter.lower() + '.xlsx', 
                               sheet_name='CCP1_DataFile_18.2')
        g_file = pd.read_excel('../CCP/data/' + quarter.upper() + '/' + ccp.upper() + '_' + 
                               quarter.lower() + '.xlsx', 
                               sheet_name='CCP1_DataFile_23')
        ex_rate = pd.read_excel('../CCP/data/kursy-walutowe-CCP.xlsx', sheet_name='Arkusz1')
    
    #for Q4-2017 till now
    elif quarter == 'Q4-2017' or quarter == 'Q1-2018' or quarter == 'Q2-2018':
        #basic
        b_file = pd.read_excel('../CCP/data/' + quarter.upper() + '/' + ccp.upper() + '_' + 
                               quarter.lower() + '.xlsx', sheet_name='AggregatedDataFile_Pagina_2')
        #files in use
        a_file = pd.read_excel('../CCP/data/' + quarter.upper() + '/' + ccp.upper() + '_' + 
                               quarter.lower() + '.xlsx', 
                               sheet_name='CCP1_DataFile_4.4a_Pagina_4')
        c_file = pd.read_excel('../CCP/data/' + quarter.upper() + '/' + ccp.upper() + '_' + 
                               quarter.lower() + '.xlsx', 
                               sheet_name='CCP1_DataFile_6.1_Pagina_6')
        d_file = pd.read_excel('../CCP/data/' + quarter.upper() + '/' + ccp.upper() + '_' + 
                               quarter.lower() + '.xlsx', 
                               sheet_name='CCP1_DataFile_6.2_Pagina_7')
        e_file = pd.read_excel('../CCP/data/' + quarter.upper() + '/' + ccp.upper() + '_' + 
                               quarter.lower() + '.xlsx', 
                               sheet_name='CCP1_DataFile_18.2_Pagina_15')
        g_file = pd.read_excel('../CCP/data/' + quarter.upper() + '/' + ccp.upper() + '_' + 
                               quarter.lower() + '.xlsx', 
                               sheet_name='CCP1_DataFile_23_Pagina_18')
        ex_rate = pd.read_excel('../CCP/data/kursy-walutowe-CCP.xlsx', sheet_name='Arkusz1')
        
    elif quarter == 'Q1-2017':
        #basic
        b_file = pd.read_excel('../CCP/data/' + quarter.upper() + 
                               '/CCG_q1-2017-AggregateDataFile_.xlsx', sheet_name='Page1_1')
        #files in use
        a_file = pd.read_excel('../CCP/data/' + quarter.upper() + 
                               '/CCG_q1-2017_4_4a__5.xlsx', 
                               sheet_name='Page1_1')
        c_file = pd.read_excel('../CCP/data/' + quarter.upper() + 
                               '/CCG_q1-2017_6_1__5.xlsx', 
                               sheet_name='Page1_1')
        d_file = pd.read_excel('../CCP/data/' + quarter.upper() + 
                               '/CCG_q1-2017_6_2__11.xlsx', 
                               sheet_name='Page1_1')
        e_file = pd.read_excel('../CCP/data/' + quarter.upper() + 
                               '/CCG_q1-2017_18_2__4.xlsx', 
                               sheet_name='Page1_1')
        g_file = pd.read_excel('../CCP/data/' + quarter.upper() + 
                               '/CCG_q1-2017_23__12.xlsx', 
                               sheet_name='Page1_1')
        ex_rate = pd.read_excel('../CCP/data/kursy-walutowe-CCP.xlsx', sheet_name='Arkusz1')
        
    elif quarter == 'Q4-2016':
        #basic
        b_file = pd.read_excel('../CCP/data/' + quarter.upper() + 
                               '/CCG_q4-2016_AggregatedDataFile__v.1.xlsx', sheet_name='Page1_1')
        #files in use
        a_file = pd.read_excel('../CCP/data/' + quarter.upper() + 
                               '/CCG_q4-2016_4_4a__4.xlsx', 
                               sheet_name='Page1_1')
        c_file = pd.read_excel('../CCP/data/' + quarter.upper() + 
                               '/CCG_q4-2016_6_1__3.xlsx', 
                               sheet_name='Page1_1')
        d_file = pd.read_excel('../CCP/data/' + quarter.upper() + 
                               '/CCG_q4-2016_6_2__9.xlsx', 
                               sheet_name='Page1_1')
        e_file = pd.read_excel('../CCP/data/' + quarter.upper() + 
                               '/CCG_q4-2016_18_2__4.xlsx', 
                               sheet_name='CCG_DataFile_18_2_')
        g_file = pd.read_excel('../CCP/data/' + quarter.upper() + 
                               '/CCG_q4-2016_23__10.xlsx', 
                               sheet_name='Page1_1')
        ex_rate = pd.read_excel('../CCP/data/kursy-walutowe-CCP.xlsx', sheet_name='Arkusz1')
        
    elif quarter == 'Q3-2016':
        #basic
        b_file = pd.read_excel('../CCP/data/' + quarter.upper() + 
                               '/CCG_q3-2016_AggregatedDataFile.xlsx', sheet_name='Page1_1')
        #files in use
        a_file = pd.read_excel('../CCP/data/' + quarter.upper() + 
                               '/CCG_q3-2016_4_4a__3.xlsx', 
                               sheet_name='Page1_1')
        c_file = pd.read_excel('../CCP/data/' + quarter.upper() + 
                               '/CCG_q3-2016_6_1__4.xlsx', 
                               sheet_name='Page1_1')
        d_file = pd.read_excel('../CCP/data/' + quarter.upper() + 
                               '/CCG_q3-2016_6_2_2016-09-30.xlsx', 
                               sheet_name='Page1_1')
        e_file = pd.read_excel('../CCP/data/' + quarter.upper() + 
                               '/CCG_q3-2016_18_2__3.xlsx', 
                               sheet_name='Page1_1')
        g_file = pd.read_excel('../CCP/data/' + quarter.upper() + 
                               '/CCG_q3-2016_23__9.xlsx', 
                               sheet_name='Page1_1')
        ex_rate = pd.read_excel('../CCP/data/kursy-walutowe-CCP.xlsx', sheet_name='Arkusz1')
    
    #final file
    f_file = pd.DataFrame({'CCP':ccp.upper()}, index=[0,1,2,3])
    f_file['quarter'] = quarter
    f_file['clearning service'] = ['equity', 'bound', 'idex', 'agrex']
    
    #due to missing columns name, columns need to be renamed
    ########################################################################################################
    values = list(b_file.iloc[1].values)
    for item in b_file.columns.values:
        b_file = b_file.rename(columns={item: values[0]})
        values.pop(0)
    b_file = b_file.drop([0,1])
    b_file = b_file.reset_index().drop(columns=['index'])
    
    values = list(a_file.iloc[1].values)
    for item in a_file.columns.values:
        a_file = a_file.rename(columns={item: values[0]})
        values.pop(0)
    a_file = a_file.drop([0,1])
    a_file = a_file.reset_index().drop(columns=['index'])
    
    values = list(c_file.iloc[1].values)
    for item in c_file.columns.values:
        c_file = c_file.rename(columns={item: values[0]})
        values.pop(0)
    c_file = c_file.drop([0,1])
    c_file = c_file.reset_index().drop(columns=['index'])
    
    values = list(d_file.iloc[1].values)
    for item in d_file.columns.values:
        d_file = d_file.rename(columns={item: values[0]})
        values.pop(0)
    d_file = d_file.drop([0,1])
    d_file = d_file.reset_index().drop(columns=['index'])
    
    values = list(e_file.iloc[1].values)
    for item in e_file.columns.values:
        e_file = e_file.rename(columns={item: values[0]})
        values.pop(0)
    e_file = e_file.drop([0,1])
    e_file = e_file.reset_index().drop(columns=['index'])
    
    values = list(g_file.iloc[1].values)
    for item in g_file.columns.values:
        g_file = g_file.rename(columns={item: values[0]})
        values.pop(0)
    g_file = g_file.drop([0,1])
    g_file = g_file.reset_index().drop(columns=['index'])
    
    #from Q2-2018 another row to dropping
    if quarter == 'Q2-2018':
        b_file = b_file.drop([4])
        b_file = b_file.reset_index().drop(columns=['index'])
    elif quarter == 'Q1-2018' or quarter == 'Q4-2017' or quarter == 'Q3-2017' or quarter == 'Q2-2017' or quarter == 'Q1-2017' or quarter == 'Q3-2016':
        b_file = b_file.drop([3])
        b_file = b_file.reset_index().drop(columns=['index'])
    else:
        pass
    
    ###########################################################################################################
    
    
    
    #extra col 'ex_rate' in files
    add_ex_rate(g_file, ex_rate, quarter)

    #recalculate to EUR

    g_file['23.1.2'] = g_file['23.1.2'] // g_file['ex_rate']
    g_file['23.2.1'] = g_file['23.2.1'] // g_file['ex_rate']
    
    f_file['4.1.1'] = b_file[b_file.ReportLevel == 'Default Fund']['4.1.1'].values
    f_file['4.1.2'] = b_file[b_file.ReportLevel == 'Default Fund']['4.1.2'].values
    f_file['4.1.3'] = b_file[b_file.ReportLevel == 'Default Fund']['4.1.3'].values
    f_file['4.1.4'] = b_file[b_file.ReportLevel == 'Default Fund']['4.1.4'].values
    f_file['4.1.5'] = b_file[b_file.ReportLevel == 'Default Fund']['4.1.5'].values
    f_file['4.1.6'] = b_file[b_file.ReportLevel == 'Default Fund']['4.1.6'].values
    f_file['4.1.7'] = b_file[b_file.ReportLevel == 'Default Fund']['4.1.7'].values
    f_file['4.1.8'] = b_file[b_file.ReportLevel == 'Default Fund']['4.1.8'].values
    f_file['4.1.9'] = b_file[b_file.ReportLevel == 'Default Fund']['4.1.9'].values
    f_file['4.1.10'] = b_file[b_file.ReportLevel == 'Default Fund']['4.1.10'].values
    
    # 4.4.7.PDA & 4.4.7.MA
    f_file['4.4.7.PDA'] = a_file[(a_file.Description == 'PeakDayAmountInPast12Months') & (a_file.ReportLevel == 'Default Fund')].reset_index()['4.4.7']
    f_file['4.4.7.MA'] = a_file[(a_file.Description == 'MeanAverageOverPrevious12Months') & (a_file.ReportLevel == 'Default Fund')].reset_index()['4.4.7']
    
    #6.1.1.CLIENT = 'Client_Net' + 'Client_Gross'
    CCG_EQUITY = sum(c_file[c_file.Description.isin(['Client Net', 'Client Gross']) & (c_file.ReportLevelIdentifier == 'CCG_EQUITY')]['6.1.1'])
    CCG_BOND = sum(c_file[c_file.Description.isin(['Client Net', 'Client Gross']) & (c_file.ReportLevelIdentifier == 'CCG_BOND')]['6.1.1'])
    CCG_IDEX = sum(c_file[c_file.Description.isin(['Client Net', 'Client Gross']) & (c_file.ReportLevelIdentifier == 'CCG_IDEX')]['6.1.1'])
    CCG_AGREX = sum(c_file[c_file.Description.isin(['Client Net', 'Client Gross']) & (c_file.ReportLevelIdentifier == 'CCG_AGREX')]['6.1.1'])
    
    f_file['6.1.1.CLIENT'] = [CCG_EQUITY, CCG_BOND, CCG_IDEX, CCG_AGREX]
    
    #6.1.1.TOTAL
    T_CCG_EQUITY = sum(c_file[c_file.Description.isin(['Total']) & (c_file.ReportLevelIdentifier == 'CCG_EQUITY')]['6.1.1'])
    T_CCG_BOND = sum(c_file[c_file.Description.isin(['Total']) & (c_file.ReportLevelIdentifier == 'CCG_BOND')]['6.1.1'])
    T_CCG_IDEX = sum(c_file[c_file.Description.isin(['Total']) & (c_file.ReportLevelIdentifier == 'CCG_IDEX')]['6.1.1'])
    T_CCG_AGREX = sum(c_file[c_file.Description.isin(['Total']) & (c_file.ReportLevelIdentifier == 'CCG_AGREX')]['6.1.1'])
    
    f_file['6.1.1.TOTAL'] = [T_CCG_EQUITY, T_CCG_BOND, T_CCG_IDEX, T_CCG_AGREX]
    
    #6.2.15.PRE & POST
    PRE_CCG_EQUITY = sum(d_file[d_file.Description.isin(['TotalIM_PreHaircut']) & (d_file.ReportLevelIdentifier == 'CCG_EQUITY')]['6.2.15'])
    PRE_CCG_BOND = sum(d_file[d_file.Description.isin(['TotalIM_PreHaircut']) & (d_file.ReportLevelIdentifier == 'CCG_BOND')]['6.2.15'])
    PRE_CCG_IDEX = sum(d_file[d_file.Description.isin(['TotalIM_PreHaircut']) & (d_file.ReportLevelIdentifier == 'CCG_IDEX')]['6.2.15'])
    PRE_CCG_AGREX = sum(d_file[d_file.Description.isin(['TotalIM_PreHaircut']) & (d_file.ReportLevelIdentifier == 'CCG_AGREX')]['6.2.15'])
    
    POST_CCG_EQUITY = sum(d_file[d_file.Description.isin(['TotalIM_PostHaircut']) & (d_file.ReportLevelIdentifier == 'CCG_EQUITY')]['6.2.15'])
    POST_CCG_BOND = sum(d_file[d_file.Description.isin(['TotalIM_PostHaircut']) & (d_file.ReportLevelIdentifier == 'CCG_BOND')]['6.2.15'])
    POST_CCG_IDEX = sum(d_file[d_file.Description.isin(['TotalIM_PostHaircut']) & (d_file.ReportLevelIdentifier == 'CCG_IDEX')]['6.2.15'])
    POST_CCG_AGREX = sum(d_file[d_file.Description.isin(['TotalIM_PostHaircut']) & (d_file.ReportLevelIdentifier == 'CCG_AGREX')]['6.2.15'])
    
    f_file['6.2.15.PRE'] = [PRE_CCG_EQUITY, PRE_CCG_BOND, PRE_CCG_IDEX, PRE_CCG_AGREX]
    f_file['6.2.15.POST'] = [POST_CCG_EQUITY, POST_CCG_BOND, POST_CCG_IDEX, POST_CCG_AGREX]

    #number of CCP
    f_file['18.1.1.1'] = b_file[b_file.ReportLevel == 'Default Fund']['18.1.1.1'].values
    f_file['18.1.1.2'] = b_file[b_file.ReportLevel == 'Default Fund']['18.1.1.2'].values
    
    #number od CCP participants (average)
    f_file['18.1.2.2'] = b_file[b_file.ReportLevel == 'Default Fund']['18.1.2.2'].values
    
    #number of clients
    f_file['19.1.1'] = b_file[b_file.ReportLevel == 'Default Fund']['19.1.1'].values
    f_file['19.1.2'] = b_file[b_file.ReportLevel == 'Default Fund']['19.1.2'].values
    
    #23.1.2.OTC and 23.2.1.OTC - do not exist
    f_file['23.1.2.OTC'] = 0
    f_file['23.2.1.OTC'] = 0
    
    #23.1.2.ETD and 23.2.1.ETD
    ETD_23_1_2_CCG_EQUITY = sum(g_file[(g_file.ReportLevelIdentifier == 'WHOLESALES')]['23.1.2'])
    ETD_23_1_2_CCG_BOND = sum(g_file[(g_file.ReportLevelIdentifier == 'RETAILS')]['23.1.2'])
    ETD_23_1_2_CCG_IDEX = sum(g_file[g_file.ReportLevelIdentifier.isin(['DERIVATES', 'EQUITIES'])]['23.1.2'])
    ETD_23_1_2_CCG_AGREX = sum(g_file[g_file.ReportLevelIdentifier.isin(['IDEX', 'AGREX'])]['23.1.2'])
    
    f_file['23.1.2.ETD'] = [ETD_23_1_2_CCG_EQUITY, ETD_23_1_2_CCG_BOND, ETD_23_1_2_CCG_IDEX, ETD_23_1_2_CCG_AGREX]
    
    ETD_23_2_1_CCG_EQUITY = sum(g_file[(g_file.ReportLevelIdentifier == 'CCG_EQUITY')]['23.2.1'])
    ETD_23_2_1_CCG_BOND = sum(g_file[(g_file.ReportLevelIdentifier == 'CCG_BOND')]['23.2.1'])
    ETD_23_2_1_CCG_IDEX = sum(g_file[(g_file.ReportLevelIdentifier == 'CCG_IDEX')]['23.2.1'])
    ETD_23_2_1_CCG_AGREX = sum(g_file[(g_file.ReportLevelIdentifier == 'CCG_AGREX')]['23.2.1'])
    
    f_file['23.2.1.ETD'] = [ETD_23_2_1_CCG_EQUITY, ETD_23_2_1_CCG_BOND, ETD_23_2_1_CCG_IDEX, ETD_23_2_1_CCG_AGREX]
    
    writer = pd.ExcelWriter("data/" + ccp.lower() + '/' + ccp.lower() + '-' + quarter.upper() + '.xlsx')
    f_file.to_excel(writer, ccp.lower() + '-' + quarter.upper())
    writer.save()

# %%
ccg_colect('Q3-2016')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-282-f1d379cac62d> in <module>
# ----> 1 ccg_colect('Q3-2016')
#
# <ipython-input-281-3416bfdabcd7> in ccg_colect(quarter)
#     128         b_file = b_file.rename(columns={item: values[0]})
#     129         values.pop(0)
# --> 130     b_file = b_file.drop([0,1])
#     131     b_file = b_file.reset_index().drop(columns=['index'])
#     132
#
# ~/Dokumenty/DataScience/CCP/myvenv/lib/python3.6/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ...
