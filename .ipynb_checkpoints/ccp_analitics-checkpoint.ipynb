# %%
import numpy as np
import pandas as pd
import openpyxl 
import os

# %matplotlib inline
import matplotlib.pyplot as plt  # Matlab-style plotting
import seaborn as sns
color = sns.color_palette()
sns.set_style('darkgrid')
import warnings
def ignore_warn(*args, **kwargs):
    pass
warnings.warn = ignore_warn #ignore annoying warning (from sklearn and seaborn)

# %%
ccp = pd.read_excel('../CCP/data/all_in_one.xlsx', sheet_name='all_in_one')
ccp.head()
# Out:
#      CCP  quarter clearning service          4.1.1    4.1.2        4.1.3  \
# 0  KELER  Q2-2017               TEA  694902.904134    16188          NaN
# 1  KELER  Q2-2017               KGA  748879.415288    16188          NaN
# 2  KELER  Q2-2017            TP KGA  358836.497556    16188          NaN
# 3  KELER  Q2-2017        CEEGEX KGA   88650.163499    16188          NaN
# 4  KELER  Q4-2017               TEA  504653.188882  16121.8  2.57948e+06
#
#           4.1.4         4.1.5 4.1.6 4.1.7      ...        6.2.15.POST  \
# 0  6.293910e+06  6.293910e+06     0     0      ...       5.149808e+07
# 1  6.782789e+06  6.782789e+06     0     0      ...       7.216904e+07
# 2  3.250072e+06  3.250072e+06     0     0      ...       1.760907e+07
# 3  8.029268e+05  8.029268e+05     0     0      ...       6.261182e+06
# 4  5.046108e+06  5.046108e+06     0     0      ...       6.036468e+07
#
#   18.1.1.1 18.1.1.2  18.1.2.2  19.1.1  19.1.2  23.1.2.OTC    23.1.2.ETD  \
# 0     11.0     10.0         0     NaN    17.0         0.0  7.419962e+06
# 1      8.0      4.0         0    1160     8.0         0.0  2.895278e+04
# 2      0.0     35.0         0     NaN     0.0         0.0  0.000000e+00
# 3      0.0     19.0         0     NaN     0.0         0.0  0.000000e+00
# 4     11.0     12.0         0     NaN    22.0         0.0  1.193287e+07
#
#    23.2.1.OTC    23.2.1.ETD
# 0         0.0  3.684394e+07
# 1         0.0  3.152465e+07
# 2         0.0  0.000000e+00
# 3         0.0  0.000000e+00
# 4         0.0  4.235150e+07
#
# [5 rows x 28 columns]

# %%
#MISSING DATA PRESENTATION
total = ccp.isnull().sum().sort_values(ascending=False)
ratio = (ccp.isnull().sum() / ccp.isnull().count()).sort_values(ascending=False)
missing = pd.concat([total, ratio], axis=1, keys=['Total', 'Ratio'])
missing.head(20)
# Out:
#               Total     Ratio
# 19.1.1           99  0.292035
# 23.1.2.ETD       96  0.283186
# 23.1.2.OTC       90  0.265487
# 23.2.1.OTC       82  0.241888
# 23.2.1.ETD       77  0.227139
# 4.1.3            75  0.221239
# 4.1.2            67  0.197640
# 4.1.6            63  0.185841
# 19.1.2           53  0.156342
# 4.1.10           49  0.144543
# 18.1.2.2         37  0.109145
# 4.1.9            37  0.109145
# 4.4.7.MA         36  0.106195
# 4.4.7.PDA        36  0.106195
# 18.1.1.1         33  0.097345
# 18.1.1.2         33  0.097345
# 4.1.8            32  0.094395
# 6.1.1.TOTAL      24  0.070796
# 6.1.1.CLIENT     21  0.061947
# 4.1.7            21  0.061947

# %%
all_data_na = (ccp.isnull().sum() / len(ccp)) * 100
all_data_na = all_data_na.drop(all_data_na[all_data_na == 0].index).sort_values(ascending=False)[:30]

f, ax = plt.subplots(figsize=(15, 12))
plt.xticks(rotation='90')
sns.barplot(x=all_data_na.index, y=all_data_na)
plt.xlabel('Features', fontsize=15)
plt.ylabel('Percent of missing values', fontsize=15)
plt.title('Percent missing data by feature', fontsize=15)
# Out:
# Text(0.5, 1.0, 'Percent missing data by feature')

# %%
ccp.dtypes
# Out:
# CCP                   object
# quarter               object
# clearning service     object
# 4.1.1                float64
# 4.1.2                 object
# 4.1.3                 object
# 4.1.4                float64
# 4.1.5                float64
# 4.1.6                 object
# 4.1.7                 object
# 4.1.8                 object
# 4.1.9                 object
# 4.1.10                object
# 4.4.7.PDA            float64
# 4.4.7.MA             float64
# 6.1.1.CLIENT         float64
# 6.1.1.TOTAL          float64
# 6.2.15.PRE           float64
# 6.2.15.POST          float64
# 18.1.1.1             float64
# 18.1.1.2             float64
# 18.1.2.2              object
# 19.1.1                object
# 19.1.2               float64
# 23.1.2.OTC           float64
# 23.1.2.ETD           float64
# 23.2.1.OTC           float64
# 23.2.1.ETD           float64
# dtype: object

# %%
#Object convertion to float64
for col in ['4.1.2', '4.1.3', '4.1.6', '4.1.7', '4.1.8', '4.1.9', '4.1.10', '18.1.2.2', '19.1.1']:
    ccp[col] = pd.to_numeric(ccp[col], errors='coerce')
    
ccp.dtypes
# Out:
# CCP                   object
# quarter               object
# clearning service     object
# 4.1.1                float64
# 4.1.2                float64
# 4.1.3                float64
# 4.1.4                float64
# 4.1.5                float64
# 4.1.6                float64
# 4.1.7                float64
# 4.1.8                float64
# 4.1.9                float64
# 4.1.10               float64
# 4.4.7.PDA            float64
# 4.4.7.MA             float64
# 6.1.1.CLIENT         float64
# 6.1.1.TOTAL          float64
# 6.2.15.PRE           float64
# 6.2.15.POST          float64
# 18.1.1.1             float64
# 18.1.1.2             float64
# 18.1.2.2             float64
# 19.1.1               float64
# 19.1.2               float64
# 23.1.2.OTC           float64
# 23.1.2.ETD           float64
# 23.2.1.OTC           float64
# 23.2.1.ETD           float64
# dtype: object

# %%
ccp.describe()
# Out:
#               4.1.1         4.1.2         4.1.3         4.1.4         4.1.5  \
# count  3.180000e+02  2.190000e+02  2.030000e+02  3.180000e+02  3.180000e+02
# mean   1.251140e+07  2.549640e+06  2.277686e+06  6.994649e+08  7.340057e+08
# std    2.739689e+07  9.435546e+06  5.744461e+06  1.257086e+09  1.326368e+09
# min    6.020000e+02  0.000000e+00  0.000000e+00  1.771255e+05  1.771255e+05
# 25%    8.707820e+05  0.000000e+00  0.000000e+00  1.257075e+07  1.257075e+07
# 50%    1.941895e+06  0.000000e+00  0.000000e+00  9.775000e+07  1.089350e+08
# 75%    1.076024e+07  0.000000e+00  1.939676e+06  9.224625e+08  9.224550e+08
# max    1.500000e+08  4.272505e+07  4.905913e+07  5.839893e+09  5.839893e+09
#
#               4.1.6         4.1.7         4.1.8         4.1.9        4.1.10  \
# count  2.190000e+02  3.020000e+02  2.990000e+02  2.820000e+02  2.490000e+02
# mean   3.303041e+06  2.556722e+07  7.354280e+08  8.503949e+08  2.096410e+07
# std    1.118125e+07  1.158104e+08  1.410868e+09  1.679239e+09  7.287132e+07
# min    0.000000e+00  0.000000e+00  0.000000e+00  1.771255e+05  0.000000e+00
# 25%    0.000000e+00  0.000000e+00  1.613526e+07  1.444571e+07  0.000000e+00
# 50%    0.000000e+00  0.000000e+00  1.340000e+08  1.348500e+08  0.000000e+00
# 75%    0.000000e+00  3.329562e+06  8.197639e+08  8.862842e+08  0.000000e+00
# max    6.528010e+07  7.000000e+08  6.603284e+09  7.618337e+09  3.841500e+08
#
#            ...        6.2.15.POST    18.1.1.1    18.1.1.2    18.1.2.2  \
# count      ...       3.330000e+02  306.000000  306.000000  267.000000
# mean       ...       2.799113e+10   18.297386   25.062092    0.198502
# std        ...       4.837529e+10   20.876996   32.613676    0.563553
# min        ...       0.000000e+00    0.000000    0.000000    0.000000
# 25%        ...       6.036468e+07    4.000000    1.000000    0.000000
# 50%        ...       1.945862e+09   11.000000   14.000000    0.000000
# 75%        ...       2.594688e+10   22.000000   29.750000    0.000000
# max        ...       1.624964e+11   87.000000  154.000000    2.000000
#
#              19.1.1      19.1.2    23.1.2.OTC    23.1.2.ETD    23.2.1.OTC  \
# count    206.000000  286.000000  2.490000e+02  2.430000e+02  2.570000e+02
# mean    3897.674757   28.835664  3.928346e+10  4.398644e+09  3.021998e+12
# std    13663.911376   46.398475  2.948042e+11  1.702619e+10  2.368372e+13
# min        0.000000    0.000000  0.000000e+00  0.000000e+00  0.000000e+00
# 25%        3.250000    4.000000  0.000000e+00  0.000000e+00  0.000000e+00
# 50%       40.500000   12.000000  0.000000e+00  2.627217e+06  0.000000e+00
# 75%      264.750000   33.000000  0.000000e+00  1.287202e+09  3.797514e+08
# max    77355.000000  225.000000  2.781279e+12  1.104689e+11  1.970147e+14
#
#          23.2.1.ETD
# count  2.620000e+02
# mean   2.086252e+10
# std    1.007038e+11
# min    0.000000e+00
# 25%    0.000000e+00
# 50%    1.903922e+08
# 75%    2.955340e+09
# max    8.476543e+11
#
# [8 rows x 25 columns]

# %%
ccp['quarter'].value_counts()
# Out:
# Q1-2018    37
# Q4-2017    37
# Q3-2017    37
# Q2-2017    37
# Q2-2018    37
# Q4-2016    36
# Q1-2017    36
# Q3-2016    32
# Q2-2016    24
# Q1-2016    21
# Q4-2015     5
# Name: quarter, dtype: int64
