# %%
import numpy as np
import pandas as pd
import openpyxl 
import os
# %run ccp_func.ipynb

# %%
def lme_colect(quarter):
    #quarter = format: 'Q3-2017'
    
    ccp = 'lme'
    reverse = quarter.split('-')
    reverse = reverse[1] + '_' + reverse[0]
    
    reverse2 = quarter.split('-')
    reverse2 = reverse2[1] + reverse2[0]
    
    try:
        b_file = pd.read_csv('../CCP/data/' + quarter.upper() + '/LMECAggregatedDataFile ' + reverse2.upper() + '.csv', encoding='cp1252')
        #files in use
        a_file = pd.read_csv('../CCP/data/' + quarter.upper() + '/LMECDataFile4 4a ' + reverse2.upper() + '.csv', encoding='cp1252')
        c_file = pd.read_csv('../CCP/data/' + quarter.upper() + '/LMECDataFile6 1 ' + reverse2.upper() + '.csv', encoding='cp1252')
        d_file = pd.read_csv('../CCP/data/' + quarter.upper() + '/LMECDataFile6.2 ' + reverse2.upper() + '.csv', encoding='cp1252')
        e_file = pd.read_csv('../CCP/data/' + quarter.upper() + '/LMECDataFile18 2 ' + reverse2.upper() + '.csv', encoding='cp1252')
        g_file = pd.read_csv('../CCP/data/' + quarter.upper() + '/LMECDataFile23 ' + reverse2.upper() + '.csv', encoding='cp1252')
        ex_rate = pd.read_excel('../CCP/data/kursy-walutowe-CCP.xlsx', sheet_name='Arkusz1')
    except:
        if quarter == 'Q2-2017':
            b_file = pd.read_csv('../CCP/data/' + quarter.upper() + '/LMEC_AggregatedDataFile_' + reverse2.upper() + '.csv', encoding='cp1252')
            #files in use
            a_file = pd.read_csv('../CCP/data/' + quarter.upper() + '/LMEC DataFile 4 4a ' + reverse2.upper() + '.csv', encoding='cp1252')
            c_file = pd.read_csv('../CCP/data/' + quarter.upper() + '/LMEC DataFile 6 1 ' + reverse2.upper() + '.csv', encoding='cp1252')
            d_file = pd.read_csv('../CCP/data/' + quarter.upper() + '/LMEC DataFile 6.2 ' + reverse2.upper() + '.csv', encoding='cp1252')
            e_file = pd.read_csv('../CCP/data/' + quarter.upper() + '/LMEC DataFile 18 2 ' + reverse2.upper() + '.csv', encoding='cp1252')
            g_file = pd.read_csv('../CCP/data/' + quarter.upper() + '/LMEC DataFile 23 ' + reverse2.upper() + '.csv', encoding='cp1252')
            ex_rate = pd.read_excel('../CCP/data/kursy-walutowe-CCP.xlsx', sheet_name='Arkusz1')
        #elif quarter == 'Q1-2017':
            #b_file = pd.read_csv('../CCP/data/' + quarter.upper() + '/LMEC_AggregatedDataFile_' + reverse2.upper() + '.csv', encoding='cp1252')
            #files in use
            #a_file = pd.read_csv('../CCP/data/' + quarter.upper() + '/LMEC_DataFile_4_4a_' + reverse2.upper() + '.csv', encoding='cp1252')
            #c_file = pd.read_csv('../CCP/data/' + quarter.upper() + '/LMEC_DataFile_6_1_' + reverse2.upper() + '.csv', encoding='cp1252')
            #missing -> d_file = pd.read_csv('../CCP/data/' + quarter.upper() + '/LMEC_DataFile_6_2_' + reverse2.upper() + '.csv', encoding='cp1252')
            #e_file = pd.read_csv('../CCP/data/' + quarter.upper() + '/LMEC_DataFile_18_2_' + reverse2.upper() + '.csv', encoding='cp1252')
            #g_file = pd.read_csv('../CCP/data/' + quarter.upper() + '/LMEC_DataFile_23_' + reverse2.upper() + '.csv', encoding='cp1252')
            #ex_rate = pd.read_excel('../CCP/data/kursy-walutowe-CCP.xlsx', sheet_name='Arkusz1')
        else:
            b_file = pd.read_csv('../CCP/data/' + quarter.upper() + '/LMEC AggregatedDataFile ' + reverse2.upper() + '.csv', encoding='cp1252')
            #files in use
            a_file = pd.read_csv('../CCP/data/' + quarter.upper() + '/LMEC DataFile 4 4a ' + reverse2.upper() + '.csv', encoding='cp1252')
            c_file = pd.read_csv('../CCP/data/' + quarter.upper() + '/LMEC DataFile 6 1 ' + reverse2.upper() + '.csv', encoding='cp1252')
            d_file = pd.read_csv('../CCP/data/' + quarter.upper() + '/LMEC DataFile 6.2 ' + reverse2.upper() + '.csv', encoding='cp1252')
            e_file = pd.read_csv('../CCP/data/' + quarter.upper() + '/LMEC DataFile 18 2 ' + reverse2.upper() + '.csv', encoding='cp1252')
            g_file = pd.read_csv('../CCP/data/' + quarter.upper() + '/LMEC DataFile 23 ' + reverse2.upper() + '.csv', encoding='cp1252')
            ex_rate = pd.read_excel('../CCP/data/kursy-walutowe-CCP.xlsx', sheet_name='Arkusz1')

    f_file = pd.DataFrame({'CCP':ccp.upper()}, index=[0])
    f_file['quarter'] = quarter
    f_file['clearning service'] = ['aggregated']
    
    if quarter == 'Q3-2017' or quarter == 'Q4-2017' or quarter == 'Q1-2018' or quarter == 'Q2-2018' or quarter == 'Q3-2018' or quarter == 'Q4-2018': 
        b_file = b_file.drop([0]).reset_index() #general description
    else:
        pass

    #to EUR
    add_ex_rate(b_file, ex_rate, quarter)
    
    try:
        b_file['4.1.1'] = b_file['4.1.1'] // b_file['ex_rate']
        b_file['4.1.2'] = b_file['4.1.2'] // b_file['ex_rate']
        b_file['4.1.3'] = b_file['4.1.3'] // b_file['ex_rate']
        b_file['4.1.4'] = b_file['4.1.4'] // b_file['ex_rate']
        b_file['4.1.5'] = b_file['4.1.5'] // b_file['ex_rate']
        b_file['4.1.6'] = b_file['4.1.6'] // b_file['ex_rate']
        b_file['4.1.7'] = b_file['4.1.7'] // b_file['ex_rate']
        b_file['4.1.8'] = b_file['4.1.8'] // b_file['ex_rate']
        b_file['4.1.9'] = b_file['4.1.9'] // b_file['ex_rate']
        b_file['4.1.10'] = b_file['4.1.10'] // b_file['ex_rate']
    except:
        b_file['4.1.1'] = pd.to_numeric(b_file['4.1.1'], errors='coerce') // b_file['ex_rate']
        b_file['4.1.2'] = pd.to_numeric(b_file['4.1.2'], errors='coerce') // b_file['ex_rate']
        b_file['4.1.3'] = pd.to_numeric(b_file['4.1.3'], errors='coerce') // b_file['ex_rate']
        b_file['4.1.4'] = pd.to_numeric(b_file['4.1.4'], errors='coerce') // b_file['ex_rate']
        b_file['4.1.5'] = pd.to_numeric(b_file['4.1.5'], errors='coerce') // b_file['ex_rate']
        b_file['4.1.6'] = pd.to_numeric(b_file['4.1.6'], errors='coerce') // b_file['ex_rate']
        b_file['4.1.7'] = pd.to_numeric(b_file['4.1.7'], errors='coerce') // b_file['ex_rate']
        b_file['4.1.8'] = pd.to_numeric(b_file['4.1.8'], errors='coerce') // b_file['ex_rate']
        b_file['4.1.9'] = pd.to_numeric(b_file['4.1.9'], errors='coerce') // b_file['ex_rate']
        b_file['4.1.10'] = pd.to_numeric(b_file['4.1.10'], errors='coerce') // b_file['ex_rate']
        
    if quarter == 'Q2-2017':
        f_file['4.1.1'] = b_file['4.1.1']
        f_file['4.1.2'] = b_file['4.1.2']
        f_file['4.1.3'] = b_file['4.1.3']
        f_file['4.1.4'] = b_file['4.1.4']
        f_file['4.1.5'] = b_file['4.1.5']
        f_file['4.1.6'] = b_file['4.1.6']
        f_file['4.1.7'] = b_file['4.1.7']
        f_file['4.1.8'] = b_file['4.1.8']
        f_file['4.1.9'] = b_file['4.1.9']
        f_file['4.1.10'] = b_file['4.1.10']
    else:
        f_file['4.1.1'] = sum(b_file[b_file['ReportLevel'] == 'Default fund']['4.1.1'])
        f_file['4.1.2'] = sum(b_file[b_file['ReportLevel'] == 'Default fund']['4.1.2'])
        f_file['4.1.3'] = sum(b_file[b_file['ReportLevel'] == 'Default fund']['4.1.3'])
        f_file['4.1.4'] = sum(b_file[b_file['ReportLevel'] == 'Default fund']['4.1.4'])
        f_file['4.1.5'] = sum(b_file[b_file['ReportLevel'] == 'Default fund']['4.1.5'])
        f_file['4.1.6'] = sum(b_file[b_file['ReportLevel'] == 'Default fund']['4.1.6'])
        f_file['4.1.7'] = sum(b_file[b_file['ReportLevel'] == 'Default fund']['4.1.7'])
        f_file['4.1.8'] = sum(b_file[b_file['ReportLevel'] == 'Default fund']['4.1.8'])
        f_file['4.1.9'] = sum(b_file[b_file['ReportLevel'] == 'Default fund']['4.1.9'])
        f_file['4.1.10'] = sum(b_file[b_file['ReportLevel'] == 'Default fund']['4.1.10'])
    
    #to EUR
    add_ex_rate(a_file, ex_rate, quarter)
    try:
        a_file['4.4.7'] = a_file['4.4.7'] // a_file['ex_rate']
    except:
        a_file['4.4.7'] = pd.to_numeric(a_file['4.4.7'], errors='coerce') // a_file['ex_rate']
    
    add_ex_rate(c_file, ex_rate, quarter)
    try:
        c_file['6.1.1'] = c_file['6.1.1'] // c_file['ex_rate']
    except:
        c_file['6.1.1'] = pd.to_numeric(c_file['6.1.1'], errors='coerce') // c_file['ex_rate']
    
    add_ex_rate(d_file, ex_rate, quarter)
    try:
        d_file['6.2.15'] = d_file['6.2.15'] // d_file['ex_rate']
    except:
        d_file['6.2.15'] = pd.to_numeric(d_file['6.2.15'], errors='coerce') // d_file['ex_rate']
    
    add_ex_rate(g_file, ex_rate, quarter)
    try:
        g_file['23.1.2'] = g_file['23.1.2'] // g_file['ex_rate']
        g_file['23.2.1'] = g_file['23.2.1'] // g_file['ex_rate']
    except:
        g_file['23.1.2'] = pd.to_numeric(g_file['23.1.2'], errors='coerce') // g_file['ex_rate']
        g_file['23.2.1'] = pd.to_numeric(g_file['23.2.1'], errors='coerce') // g_file['ex_rate']
    
    # 4.4.7.PDA & 4.4.7.MA
    f_file['4.4.7.PDA'] = sum(a_file[a_file.Description == 'PeakDayAmountInPast12Months']['4.4.7'])
    f_file['4.4.7.MA'] = sum(a_file[a_file.Description == 'MeanAverageOverPrevious12Months']['4.4.7'])
    
    #6.1.1.CLIENT = 'Client_Net'
    f_file['6.1.1.CLIENT'] = sum(c_file[c_file.Description.isin(['Client_Net'])]['6.1.1'])
    
    #6.1.1.TOTAL = 'Total'
    f_file['6.1.1.TOTAL'] = sum(c_file[c_file.Description.isin(['Total'])]['6.1.1'])

    
    #6.2.15.PRE & POST
    f_file['6.2.15.PRE'] = float(d_file[d_file.Description.isin(['TotalIM_PreHaircut'])]['6.2.15'].values)
    f_file['6.2.15.POST'] = float(d_file[d_file.Description.isin(['TotalIM_PostHaircut'])]['6.2.15'].values)
    
    #number of CCP
    f_file['18.1.1.1'] = sum(b_file[b_file['ReportLevel'] == 'Default fund']['18.1.1.1'])
    f_file['18.1.1.2'] = sum(b_file[b_file['ReportLevel'] == 'Default fund']['18.1.1.2'])

    #number od CCP participants (average)
    f_file['18.1.2.2'] = sum(b_file[b_file['ReportLevel'] == 'Default fund']['18.1.2.2'])

    #number of clients
    f_file['19.1.1'] = sum(b_file[b_file['ReportLevel'] == 'Default fund']['19.1.1'])
    f_file['19.1.2'] = sum(b_file[b_file['ReportLevel'] == 'Default fund']['19.1.2'])
    
    #23.1.2.OTC & ETD
    f_file['23.1.2.OTC'] = sum(g_file[(g_file['ReportLevel'] == 'Default fund') & (g_file['Description'].map(lambda x: 'OTC' in x) == True)]['23.1.2'])
    f_file['23.1.2.ETD'] = sum(g_file[(g_file['ReportLevel'] == 'Default fund') & (g_file['Description'].map(lambda x: 'ETD' in x) == True)]['23.1.2'])

    #23.2.1.OTC & ETD
    f_file['23.2.1.OTC'] = sum(g_file[(g_file['ReportLevel'] == 'Default fund') & (g_file['Description'].map(lambda x: 'OTC' in x) == True)]['23.2.1'])
    f_file['23.2.1.ETD'] = sum(g_file[(g_file['ReportLevel'] == 'Default fund') & (g_file['Description'].map(lambda x: 'ETD' in x) == True)]['23.2.1'])

    #ccp_save(ccp, quarter, f_file)
